# %%
import time
import datetime
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import tensorflow as tf
import numpy as np
import keras # keras.metrics
import shutil
import matplotlib.pyplot as plt
import os

# %%
from keras.models import load_model
# load model
model = load_model('lstm_model.h5')

print(model)
# Out:
# <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001BE84AC17F0>

# %%
hist=pd.read_csv(r'C:\Users\oguzh\Downloads\bist100.csv')
hist.head(9)
# Out:
#          Date          Open          High           Low         Close  \
# 0  2005-01-10  25185.000000  25731.500000  25142.000000  25604.699219
# 1  2005-01-11  25604.699219  26181.099609  25582.000000  26110.199219
# 2  2005-01-12  26110.199219  26575.000000  25804.099609  26271.300781
# 3  2005-01-13  26271.300781  26565.599609  26081.800781  26493.000000
# 4  2005-01-14  26493.000000  26749.800781  26240.099609  26362.699219
# 5  2005-01-17  26362.699219  26863.199219  26359.900391  26863.199219
# 6  2005-01-18  26863.199219  26905.900391  26624.300781  26813.099609
# 7  2005-01-19  26813.099609  26918.099609  26443.199219  26918.099609
# 8  2005-01-20           NaN           NaN           NaN           NaN
#
#       Adj Close       Volume
# 0  25604.699219  363568400.0
# 1  26110.199219  405221100.0
# 2  26271.300781  394794800.0
# 3  26493.000000  377036800.0
# 4  26362.699219  508805700.0
# 5  26863.199219  300817900.0
# 6  26813.099609  249121400.0
# 7  26918.099609  141374100.0
# 8           NaN          NaN

# %%
hist.isnull().sum()
hist=hist.dropna()
hist.head(9)
# Out:
#           Date          Open          High           Low         Close  \
# 0   2005-01-10  25185.000000  25731.500000  25142.000000  25604.699219
# 1   2005-01-11  25604.699219  26181.099609  25582.000000  26110.199219
# 2   2005-01-12  26110.199219  26575.000000  25804.099609  26271.300781
# 3   2005-01-13  26271.300781  26565.599609  26081.800781  26493.000000
# 4   2005-01-14  26493.000000  26749.800781  26240.099609  26362.699219
# 5   2005-01-17  26362.699219  26863.199219  26359.900391  26863.199219
# 6   2005-01-18  26863.199219  26905.900391  26624.300781  26813.099609
# 7   2005-01-19  26813.099609  26918.099609  26443.199219  26918.099609
# 10  2005-01-24  26918.099609  26952.500000  26322.400391  26469.400391
#
#        Adj Close       Volume
# 0   25604.699219  363568400.0
# 1   26110.199219  405221100.0
# 2   26271.300781  394794800.0
# 3   26493.000000  377036800.0
# 4   26362.699219  508805700.0
# 5   26863.199219  300817900.0
# 6   26813.099609  249121400.0
# 7   26918.099609  141374100.0
# 10  26469.400391  328953400.0

# %%
temp=pd.read_csv(r'C:\Users\oguzh\Downloads\XU1002.csv')
temp.head(9)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2020-07-27  1199.599976  1203.400024  1194.400024  1195.699951
# 1  2020-07-28  1197.099976  1198.199951  1152.699951  1152.699951
# 2  2020-07-29  1156.000000  1159.699951  1121.000000  1135.599976
# 3  2020-07-30  1137.199951  1137.199951  1124.599976  1126.900024
# 4  2020-08-04  1140.400024  1143.300049  1064.900024  1087.199951
# 5  2020-08-05  1095.300049  1100.599976  1066.099976  1091.800049
# 6  2020-08-06  1090.599976  1093.699951  1033.800049  1034.400024
# 7  2020-08-07  1030.300049  1062.099976   985.400024  1060.599976
# 8  2020-08-10  1055.599976  1078.900024  1039.000000  1075.500000
#
#      Adj Close        Volume
# 0  1195.699951  2.729247e+09
# 1  1152.699951  4.094110e+09
# 2  1135.599976  4.345012e+09
# 3  1126.900024  1.403498e+09
# 4  1087.199951  4.294045e+09
# 5  1091.800049  4.574041e+09
# 6  1034.400024  5.070717e+09
# 7  1060.599976  6.044999e+09
# 8  1075.500000  3.799076e+09

# %%
temp['Open'] = temp['Open']*100.00
temp['High'] = temp['High']*100.00
temp['Low'] = temp['Low']*100.00
temp['Close'] = temp['Close']*100.00
temp['Adj Close'] = temp['Adj Close']*100.00

# %%
temp=temp.dropna()
temp.head(9)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2020-07-27  119959.9976  120340.0024  119440.0024  119569.9951
# 1  2020-07-28  119709.9976  119819.9951  115269.9951  115269.9951
# 2  2020-07-29  115600.0000  115969.9951  112100.0000  113559.9976
# 3  2020-07-30  113719.9951  113719.9951  112459.9976  112690.0024
# 4  2020-08-04  114040.0024  114330.0049  106490.0024  108719.9951
# 5  2020-08-05  109530.0049  110059.9976  106609.9976  109180.0049
# 6  2020-08-06  109059.9976  109369.9951  103380.0049  103440.0024
# 7  2020-08-07  103030.0049  106209.9976   98540.0024  106059.9976
# 8  2020-08-10  105559.9976  107890.0024  103900.0000  107550.0000
#
#      Adj Close        Volume
# 0  119569.9951  2.729247e+09
# 1  115269.9951  4.094110e+09
# 2  113559.9976  4.345012e+09
# 3  112690.0024  1.403498e+09
# 4  108719.9951  4.294045e+09
# 5  109180.0049  4.574041e+09
# 6  103440.0024  5.070717e+09
# 7  106059.9976  6.044999e+09
# 8  107550.0000  3.799076e+09

# %%
historical = hist.append(temp, ignore_index=True)
historical.tail(83)
# Out:
#             Date         Open         High          Low        Close  \
# 4005  2020-12-24  142019.9951  143230.0049  141540.0024  142600.0000
# 4006  2020-12-28  143169.9951  144280.0049  143169.9951  143930.0049
# 4007  2020-12-29  144300.0000  145969.9951  143619.9951  145969.9951
# 4008  2020-12-30  146309.9976  148319.9951  146309.9976  147990.0024
# 4009  2020-12-31  148080.0049  148440.0024  147030.0049  147669.9951
# ...          ...          ...          ...          ...          ...
# 4083  2021-04-16  140550.0000  141259.9976  140050.0000  140809.9976
# 4084  2021-04-19  140990.0024  141600.0000  137719.9951  137719.9951
# 4085  2021-04-20  137640.0024  138590.0024  135730.0049  136530.0049
# 4086  2021-04-21  136390.0024  136550.0000  130850.0000  133050.0000
# 4087  2021-04-22  132019.9951  134550.0000  130919.9951  134519.9951
#
#         Adj Close        Volume
# 4005  142600.0000  5.263356e+09
# 4006  143930.0049  2.977132e+09
# 4007  145969.9951  3.420867e+09
# 4008  147990.0024  4.193082e+09
# 4009  147669.9951  3.422724e+09
# ...           ...           ...
# 4083  140809.9976  2.315176e+09
# 4084  137719.9951  2.490438e+09
# 4085  136530.0049  2.563179e+09
# 4086  133050.0000  2.306411e+09
# 4087  134519.9951  2.092727e+09
#
# [83 rows x 7 columns]

# %%
def prepare_train_test(training_scaled, testing_scaled):
    x_train = []
    y_train = []
    for i in range(60, len(training_scaled)):
        x_train.append(training_scaled[i-60:i, 0])
        y_train.append(training_scaled[i, 0])
    
    x_test= []
    y_test = []
    
    for i in range(60, len(testing_scaled)):
        x_test.append(testing_scaled[i-60:i, 0])
        y_test.append(testing_scaled[i, 0])
    
    x_train, y_train, x_test, y_test = np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)
    
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
    return x_train, y_train, x_test, y_test

# %%
training = historical[["Close"]].values

# %%
scaler = MinMaxScaler(feature_range = (0, 1))
training_scaled= scaler.fit_transform(training)
testing_scaled = training_scaled[-400:]
training_scaled = training_scaled[-4000:-400]

# %%
print(len(testing_scaled), len(training_scaled))
# Out:
# 400 3600

# %%
X_train, y_train, X_test, y_test= prepare_train_test(training_scaled, testing_scaled)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 200)           161600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 200)           320800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 100)           120400
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 683,301
# Trainable params: 683,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs = 50, batch_size = 60)
# Out:
# Epoch 1/50
# 59/59 [==============================] - 20s 263ms/step - loss: 1.3501e-04
# Epoch 2/50
# 59/59 [==============================] - 15s 252ms/step - loss: 1.2721e-04
# Epoch 3/50
# 59/59 [==============================] - 16s 265ms/step - loss: 1.1430e-04
# Epoch 4/50
# 59/59 [==============================] - 19s 317ms/step - loss: 1.2007e-04
# Epoch 5/50
# 59/59 [==============================] - 18s 300ms/step - loss: 1.1800e-04
# Epoch 6/50
# 59/59 [==============================] - 21s 355ms/step - loss: 1.1099e-04
# Epoch 7/50
# 59/59 [==============================] - 18s 306ms/step - loss: 1.0107e-04
# Epoch 8/50
# 59/59 [==============================] - 18s 305ms/step - loss: 9.3840e-05
# Epoch 9/50
# 59/59 [==============================] - 18s 298ms/step - loss: 9.1165e-05
# Epoch 10/50
# 59/59 [==============================] - 20s 341ms/step - loss: 9.2962e-05
# Epoch 11/50
# 59/59 [==============================] - 19s 321ms/step - loss: 8.7795e-05
# Epoch 12/50
# 59/59 [==============================] - 18s 299ms/step - loss: 1.0663e-04
# Epoch 13/50
# 59/59 [==============================] - 18s 304ms/step - loss: 1.1792e-04
# Epoch 14/50
# 59/59 [==============================] - 18s 310ms/step - loss: 9.3015e-05
# Epoch 15/50
# 59/59 [==============================] - 18s 312ms/step - loss: 8.3077e-05
# Epoch 16/50
# 59/59 [==============================] - 18s 301ms/step - loss: 9.2746e-05
# Epoch 17/50
# 59/59 [==============================] - 18s 308ms/step - loss: 1.0422e-04
# Epoch 18/50
# 59/59 [==============================] - 18s 299ms/step - loss: 8.5491e-05
# Epoch 19/50
# 59/59 [==============================] - 17s 296ms/step - loss: 7.9000e-05
# Epoch 20/50
# 59/59 [==============================] - 18s 301ms/step - loss: 1.0305e-04
# Epoch 21/50
# 59/59 [==============================] - 18s 300ms/step - loss: 8.2157e-05
# Epoch 22/50
# 59/59 [==============================] - 18s 298ms/step - loss: 1.0111e-04
# Epoch 23/50
# 59/59 [==============================] - 18s 298ms/step - loss: 9.9729e-05
# Epoch 24/50
# 59/59 [==============================] - 18s 304ms/step - loss: 8.8381e-05
# Epoch 25/50
# 59/59 [==============================] - 18s 302ms/step - loss: 9.0058e-05
# Epoch 26/50
# 59/59 [==============================] - 17s 295ms/step - loss: 7.8173e-05
# Epoch 27/50
# 59/59 [==============================] - 18s 302ms/step - loss: 8.1527e-05
# Epoch 28/50
# 59/59 [==============================] - 18s 297ms/step - loss: 9.2147e-05
# Epoch 29/50
# 59/59 [==============================] - 18s 300ms/step - loss: 8.2489e-05
# Epoch 30/50
# 59/59 [==============================] - 18s 305ms/step - loss: 8.1348e-05
# Epoch 31/50
# 59/59 [==============================] - 18s 313ms/step - loss: 8.9132e-05
# Epoch 32/50
# 59/59 [==============================] - 19s 329ms/step - loss: 7.8445e-05
# Epoch 33/50
# 59/59 [==============================] - 24s 400ms/step - loss: 1.2901e-04
# Epoch 34/50
# 59/59 [==============================] - 24s 399ms/step - loss: 9.3071e-05
# Epoch 35/50
# 59/59 [==============================] - 24s 402ms/step - loss: 8.6092e-05
# Epoch 36/50
# 59/59 [==============================] - 23s 398ms/step - loss: 8.5841e-05
# Epoch 37/50
# 59/59 [==============================] - 23s 395ms/step - loss: 7.1407e-05
# Epoch 38/50
# 59/59 [==============================] - 23s 398ms/step - loss: 8.9136e-05
# Epoch 39/50
# 59/59 [==============================] - 23s 396ms/step - loss: 8.5589e-05
# Epoch 40/50
# 59/59 [==============================] - 23s 395ms/step - loss: 8.0887e-05
# Epoch 41/50
# 59/59 [==============================] - 23s 398ms/step - loss: 8.2908e-05
# Epoch 42/50
# 59/59 [==============================] - 24s 400ms/step - loss: 7.7608e-05
# Epoch 43/50
# 59/59 [==============================] - 24s 398ms/step - loss: 7.4106e-05
# Epoch 44/50
# 59/59 [==============================] - 24s 399ms/step - loss: 7.8721e-05
# Epoch 45/50
# 59/59 [==============================] - 23s 395ms/step - loss: 9.2281e-05
# Epoch 46/50
# 59/59 [==============================] - 23s 383ms/step - loss: 9.2368e-05
# Epoch 47/50
# 59/59 [==============================] - 22s 375ms/step - loss: 1.0831e-04
# Epoch 48/50
# 59/59 [==============================] - 22s 374ms/step - loss: 7.4647e-05
# Epoch 49/50
# 59/59 [==============================] - 22s 374ms/step - loss: 8.2467e-05
# Epoch 50/50
# 59/59 [==============================] - 22s 374ms/step - loss: 7.9693e-05

# %%
def training_loss_graph(history):
    plt.plot(history.history['loss'], label = 'Training  Loss')
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel('Loss')
    plt.show()
training_loss_graph(history)

# %%
def get_predicted_INV_scaled(X_test):
    predicted_prices = model.predict(X_test)
    predicted_prices = scaler.inverse_transform(predicted_prices)
    
    
    prices = scaler.inverse_transform([y_test])
    return prices, predicted_prices
prices, predicted_prices = get_predicted_INV_scaled(X_test)

# %%
def show_graph_result(prices, predicted_prices):
    index = historical.index.values[-len(prices[0]):]
    test_result = pd.DataFrame(columns = ['real', 'predicted'])
    test_result['real'] = prices[0]
    test_result['predicted'] = predicted_prices
    test_result.index = index
    
    test_result.plot(figsize = (16, 10))
    plt.title("Actual and Predicted")
    plt.ylabel("Price")
    plt.xlabel("Date")
    plt.show()
show_graph_result(prices, predicted_prices)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

def show_error_result(prices, predicted_prices):
    RMSE = math.sqrt(mean_squared_error(prices[0],predicted_prices,squared = False))
    print((mean_squared_error(prices[0],predicted_prices,squared = False)))
    print(r2_score(prices[0],predicted_prices))
    print(RMSE)
          
show_error_result(prices, predicted_prices)
# Out:
# 2576.8255357445983
# 0.9813864487942756
# 50.762442176717606

# %%
x_input=testing_scaled[300:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [0.8195295603558577,
#  0.8196767869921611,
#  0.8236528979867417,
#  0.8236528979867417,
#  0.8229165844083981,
#  0.8302797201918328,
#  0.8379373998144442,
#  0.8402199534994694,
#  0.8529581246539202,
#  0.8661381561141075,
#  0.8711451237898948,
#  0.869009796741173,
#  0.8740903781032685,
#  0.8806435873583649,
#  0.8630456744281167,
#  0.8782137164704662,
#  0.8875648628360626,
#  0.8936763016156788,
#  0.903469308287012,
#  0.918490033126488,
#  0.933363621159917,
#  0.9310073639583267,
#  0.9447764816242405,
#  0.9405058275267968,
#  0.9521396174076753,
#  0.9645096317729542,
#  0.9780578200223133,
#  0.9748180218697626,
#  0.9846110285410958,
#  0.9918269376882272,
#  0.982475701492374,
#  0.9662031890825094,
#  0.9899861537423684,
#  0.9960238890054196,
#  0.9992636864216566,
#  0.9861572693840912,
#  0.9794568334926916,
#  0.9777632761831363,
#  0.9747444089197677,
#  0.9238651583277606,
#  0.9469118094092761,
#  0.928651196586993,
#  0.9426411545755187,
#  0.9565574988777359,
#  0.9729036249739091,
#  0.9738608679688072,
#  0.9681911996646715,
#  0.9738608679688072,
#  0.9806349175465154,
#  0.9828438582815457,
#  0.9817393879140306,
#  0.9764379654930093,
#  0.9941831050595609,
#  0.97967776364556,
#  0.9780578200223133,
#  0.9823284741197571,
#  0.9925632512665705,
#  0.9854209558057478,
#  0.9613435371369685,
#  0.935646175581256,
#  0.9394749701092766,
#  0.9271049557439976,
#  0.9684121298175399,
#  0.9693693735487516,
#  0.9710628410280504,
#  0.9761434223901462,
#  0.9790886767035201,
#  0.9704738439162668,
#  0.9843900983882274,
#  0.995950275319111,
#  0.9897652235895,
#  0.9904279234815352,
#  0.9890289100111567,
#  1.0,
#  0.9938885619566977,
#  0.9856418852223026,
#  0.969516600185055,
#  0.8592904935864045,
#  0.8578914793797126,
#  0.8847669249892487,
#  0.8704088102115513,
#  0.8614257308048698,
#  0.8690834104274814,
#  0.8714396676290717,
#  0.8684207097991328,
#  0.894118072091159,
#  0.9055309325554826,
#  0.8897001906210982,
#  0.8877121793026226,
#  0.8867549363077243,
#  0.8695251801666479,
#  0.8567870090121974,
#  0.8586277929580559,
#  0.8813061974201433,
#  0.8802754305691931,
#  0.8804962708918049,
#  0.8577441629131526,
#  0.8489821034895961,
#  0.8233583548838783,
#  0.8341821284061619]

# %%
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i